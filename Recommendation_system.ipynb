# %% [markdown]
# <a href="https://colab.research.google.com/github/SanketJ29/SanketJ29/blob/main/Recommendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import re
import pickle
import operator
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from scipy.sparse import csr_matrix
from pandas.api.types import is_numeric_dtype
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

import warnings
warnings.filterwarnings("ignore")

# %%
books = pd.read_csv(r"/gdrive/MyDrive/BX-Books.csv", delimiter=';', error_bad_lines=False, encoding='ISO-8859-1', warn_bad_lines=False)
users = pd.read_csv(r"/gdrive/MyDrive/BX-Users.csv", delimiter=';', error_bad_lines=False, encoding='ISO-8859-1', warn_bad_lines=False)
ratings = pd.read_csv(r"/gdrive/MyDrive/BX-Book-Ratings.csv", delimiter=';', error_bad_lines=False, encoding='ISO-8859-1', warn_bad_lines=False)

print("Books Data:    ", books.shape)
print("Users Data:    ", users.shape)
print("Books-ratings: ", ratings.shape)

# %%
## Books Dataset Preprocessing 
print("Columns: ", list(books.columns))
books.head()

# %%
## Drop URL columns
books.drop(['Image-URL-S', 'Image-URL-M', 'Image-URL-L'], axis=1, inplace=True)
books.head()

# %%
## Checking for null values
books.isnull().sum()

# %%
books.loc[books['Book-Author'].isnull(),:]

# %%
books.loc[books['Publisher'].isnull(),:]

# %%
books.at[187689 ,'Book-Author'] = 'Other'

books.at[128890 ,'Publisher'] = 'Other'
books.at[129037 ,'Publisher'] = 'Other'

# %%
## Checking for column Year-of-publication
books['Year-Of-Publication'].unique()

# %%
pd.set_option('display.max_colwidth', -1)

# %%
books.loc[books['Year-Of-Publication'] == 'DK Publishing Inc',:]

# %%
books.loc[books['Year-Of-Publication'] == 'Gallimard',:]

# %%
books.at[209538 ,'Publisher'] = 'DK Publishing Inc'
books.at[209538 ,'Year-Of-Publication'] = 2000
books.at[209538 ,'Book-Title'] = 'DK Readers: Creating the X-Men, How It All Began (Level 4: Proficient Readers)'
books.at[209538 ,'Book-Author'] = 'Michael Teitelbaum'

books.at[221678 ,'Publisher'] = 'DK Publishing Inc'
books.at[221678 ,'Year-Of-Publication'] = 2000
books.at[209538 ,'Book-Title'] = 'DK Readers: Creating the X-Men, How Comic Books Come to Life (Level 4: Proficient Readers)'
books.at[209538 ,'Book-Author'] = 'James Buckley'

books.at[220731 ,'Publisher'] = 'Gallimard'
books.at[220731 ,'Year-Of-Publication'] = '2003'
books.at[209538 ,'Book-Title'] = 'Peuple du ciel - Suivi de Les bergers '
books.at[209538 ,'Book-Author'] = 'Jean-Marie Gustave Le ClÃ?Â©zio'

# %%
## Converting year of publication in Numbers
books['Year-Of-Publication'] = books['Year-Of-Publication'].astype(int)

# %%
books.info()

# %%
books.head()

# %%
## Users Dataset Preprocessing
print("Columns: ", list(users.columns))
users.head()

# %%
## Checking null values
print(users.isna().sum())

# %%
## Check for all values present in Age column
print(sorted(list(users['Age'].unique())))

# %%
required = users[users['Age'] <= 80]
required = required[required['Age'] >= 10]

# %%
mean = round(required['Age'].mean())   
mean

# %%
users.loc[users['Age'] > 80, 'Age'] = mean    #outliers with age grater than 80 are substituted with mean 
users.loc[users['Age'] < 10, 'Age'] = mean    #outliers with age less than 10 years are substitued with mean
users['Age'] = users['Age'].fillna(mean)      #filling null values with mean
users['Age'] = users['Age'].astype(int)       #changing Datatype to int

# %%
users.info()

# %%
users.head()

# %%
## Books rating dataset Preprocessing
print("Columns: ", list(ratings.columns))
ratings.head()

# %%
## Checking for null values
ratings.isnull().sum()

# %%
## checking all ratings number or not
print(is_numeric_dtype(ratings['Book-Rating']))

# %%
ratings.info()

# %%
ratings.head()

# %%
## Merging all three tables
dataset = pd.merge(books, ratings, on='ISBN', how='inner')
dataset = pd.merge(dataset, users, on='User-ID', how='inner')
dataset.info()

# %%
## Explicit Ratings Dataset
dataset1 = dataset[dataset['Book-Rating'] != 0]
dataset1 = dataset1.reset_index(drop = True)
dataset1.shape

# %%
## Implicit Ratings Dataset
dataset2 = dataset[dataset['Book-Rating'] == 0]
dataset2 = dataset2.reset_index(drop = True)
dataset2.shape

# %%
dataset1.head()

# %%
## Representation of Top book authors
plt.figure(figsize=(15,6))
sns.countplot(y="Book-Author", data=books,order=books['Book-Author'].value_counts().index[0:15])
plt.title("No of books by an author (Top 15)")

# %%
## Representation of Top rated books
plt.figure(figsize=(15,8))
sns.countplot(y="Book-Title", data=dataset, order=dataset['Book-Title'].value_counts().index[0:15])
plt.title("Number of Ratings for a book (Top 15)")

# %%
## RECOMMENDATION STYSTEM
bookName = input("Enter a book name: ")
number = int(input("Enter number of books to recommend: "))

# %%
def printBook(k, n):
    z = k['Book-Title'].unique()
    for x in range(len(z)):
        print(z[x])
        if x >= n-1:
            break

# %%
def get_books(dataframe, name, n):
    print("\nBooks by same Author:\n")
    au = dataframe['Book-Author'].unique()

    data = dataset1[dataset1['Book-Title'] != name]

    if au[0] in list(data['Book-Author'].unique()):
        k2 = data[data['Book-Author'] == au[0]]
    k2 = k2.sort_values(by=['Book-Rating'])
    printBook(k2, n)

    print("\n\nBooks by same Publisher:\n")
    au = dataframe['Publisher'].unique()

    if au[0] in list(data['Publisher'].unique()):
        k2 = pd.DataFrame(data[data['Publisher'] == au[0]])
    k2=k2.sort_values(by=['Book-Rating']) 
    printBook(k2, n)

# %%
if bookName in list(dataset1['Book-Title'].unique()):
    d = dataset1[dataset1['Book-Title'] == bookName]
    get_books(d, bookName, number)
else:
    print("Book Not Found!!")

# %%
## Books popoular yearly
data = pd.DataFrame(dataset1.groupby('ISBN')['Book-Rating'].count()).sort_values('Book-Rating', ascending=False)
data = pd.merge(data, books, on='ISBN', left_index = False)

years = set()
indices = []
for ind, row in data.iterrows():
    if row['Year-Of-Publication'] in years:
        indices.append(ind)
    else:
        years.add(row['Year-Of-Publication'])

data = data.drop(indices)
data = data.drop('Book-Rating', axis = 1)
data = data.sort_values('Year-Of-Publication')

pd.set_option("display.max_rows", None, "display.max_columns", None)
data
# Out:
#               ISBN  \
# 199     0099771519
# 50958   964442011X
# 51049   9643112136
# 130403  0781228956
# 92641   1551103982
# 122731  0671825356
# 45038   0373226888
# 104397  038528120X
# 103215  0404089119
# 25641   0911662251
# 54283   0877850836
# 5181    0684717603
# 23741   0440772095
# 138194  0486600815
# 43202   0023381205
# 22701   0684718081
# 10647   0448089033
# 50654   9997520858
# 7190    0684717972
# 1609    0448095017
# 129743  074752694X
# 12323   0448095076
# 62699   0804617279
# 82320   0961505109
# 53389   0882436600
# 16453   068483068X
# 20542   0802812201
# 9375    0395071224
# 50711   999750805X
# 36882   0590031236
# 36522   0486206173
# 9284    0060901012
# 22813   0152465030
# 101864  0394906012
# 11400   0060263954
# 7724    0448060043
# 15263   0448095246
# 19388   0717802418
# 15266   0448095262
# 10120   0553213601
# 4987    081120068X
# 4208    0060263857
# 1118    0064400026
# 2124    0395083567
# 5202    0156838389
# 3474    0872860175
# 1013    039480001X
# 3572    0394800028
# 119     0399501487
# 1746    0394800168
# 3573    0394800206
# 8265    0140441212
# 2276    039480029X
# 2107    0060256656
# 754     0553210092
# 2618    055314300X
# 5985    0140430229
# 504     0156528207
# 4541    0440435749
# 1193    0020442203
# 737     0440439884
# 1095    0553213695
# 1877    0394404289
# 302     0064400557
# 1825    038000321X
# 137     0380002930
# 2550    0380014300
# 263     0380018179
# 1705    0440901588
# 545     0671250671
# 469     0553208845
# 174     0553272535
# 132     0140067477
# 186     0553250426
# 385     0671617028
# 48      0345339681
# 46      0345342968
# 23      0446310786
# 106     0060915544
# 37      0345361792
# 13      0316769487
# 24      044021145X
# 16      0345337662
# 33      0804106304
# 12      067976402X
# 25      0671003755
# 4       0060928336
# 3       0312195516
# 5       059035342X
# 17      0375727345
# 8       044023722X
# 0       0316666343
# 2       0385504209
# 1       0971880107
# 2718    1881273156
# 78636   1903436346
# 134112  0743457226
# 106324  0394172116
# 30975   068107468X
# 37056   0590085417
# 19470   3442436893
# 13544   0671746103
# 124233  068471809X
# 30761   0394701658
# 23915   0140301690
#
#                                                                                                                    Book-Title  \
# 199     Memoirs of a Geisha Uk
# 50958   Tasht-i khun
# 51049   Dalan-i bihisht (Dastan-i Irani)
# 130403  Complete Works 10 Volumes [2,6,7,8,9] (Notable American Authors)
# 92641   The Cycling Adventures of Coconut Head: A North American Odyssey
# 122731  W D HSE PLANTS
# 45038   Tommy's Mom
# 104397  CATCH 22
# 103215  Charlotte Bronte and Her Sisters
# 25641   Kybalion: A Study of the Hermetic Philosophy of Ancient Egypt and Greece
# 54283   The Spiritual Life/The Word of God
# 5181    The GREAT GATSBY (Scribner Classic)
# 23741   RAMONA THE PEST (Ramona Quimby (Paperback))
# 138194  Principle of Relativity (Dover Books on Physics)
# 43202   Great Gatsby, The
# 22701   The Sun Also Rises
# 10647   The Secret of the Old Mill (The Hardy Boys Mystery Stories, Book 3)
# 50654   Beau Ideal
# 7190    Farewell to Arms
# 1609    The Secret of the Old Clock (Nancy Drew Mystery Stories, No 1)
# 129743  Bloomsbury Good Reading Guide
# 12323   The Clue in the Diary (Nancy Drew Mystery Stories Number 7)
# 62699   Legends of Angria,
# 82320   Narrow Land: Folk Chronicles of Old Cape Cod (Chatham Historical Society)
# 53389   Through the Bible Book by Book: Genesis to Esthe/Part 1 (Through the Bible Book by Book)
# 16453   Gone With the Wind
# 20542   Descent into Hell
# 9375    The Hobbit
# 50711   The Happy Highwayman
# 36882   Strangely Enough
# 36522   Rubinstein's Chess Masterpieces
# 9284    Brave New World &amp; Brave New World Revisited
# 22813   The Little Prince
# 101864  The Black Stallion
# 11400   Stuart Little 60th Anniversary Edition
# 7724    Alice in Wonderland and Through the Looking Glass (Illustrated Junior Library)
# 15263   The Clue in the Old Album (Nancy Drew Mystery Stories, No 24)
# 19388   Manifesto of the Communist Party
# 15266   Clue of the Leaning Chimney (Nancy Drew (Hardcover))
# 10120   Cyrano De Bergerac (Bantam Classics)
# 4987    Siddhartha
# 4208    Charlotte's Web
# 1118    Little House on the Prairie
# 2124    My Antonia
# 5202    Sophocles, The Oedipus Cycle: Oedipus Rex, Oedipus at Colonus, Antigone
# 3474    Howl and Other Poems (Pocket Poets)
# 1013    The Cat in the Hat
# 3572    The Cat in the Hat Comes Back (I Can Read It All by Myself Beginner Books)
# 119     Lord of the Flies
# 1746    Green Eggs and Ham (I Can Read It All by Myself Beginner Books)
# 3573    Go, Dog, Go (I Can Read It All by Myself Beginner Books)
# 8265    Bhagavad Gita (Penguin Classics)
# 2276    Hop on Pop (I Can Read It All by Myself Beginner Books)
# 2107    The Giving Tree
# 754     The Scarlet Letter
# 2618    Bourne Identity
# 5985    Gulliver's Travels (Penguin Classics)
# 504     The Little Prince
# 4541    The High King (Chronicles of Prydain (Paperback))
# 1193    Lion, the Witch and the Wardrobe
# 737     Island of the Blue Dolphins
# 1095    The Metamorphosis (Bantam Classics)
# 1877    The Prophet
# 302     Charlotte's Web (Trophy Newbery)
# 1825    Alive : The Story of the Andes Survivors (Avon Nonfiction)
# 137     Watership Down
# 2550    Nine Princes In Amber
# 263     The Thorn Birds
# 1705    A Swiftly Tilting Planet
# 545     ROAD LESS TRAVELED : A New Psychology of Love, Traditional Values, and Spritual Growth (Touchstone Books (Paperback))
# 469     Siddhartha
# 174     Night
# 132     The Tao of Pooh
# 186     The Clan of the Cave Bear (Earth's Children (Paperback))
# 385     The Color Purple
# 48      The Hobbit : The Enchanting Prelude to The Lord of the Rings
# 46      Fahrenheit 451
# 23      To Kill a Mockingbird
# 106     The Bean Trees
# 37      A Prayer for Owen Meany
# 13      The Catcher in the Rye
# 24      The Firm
# 16      Interview with the Vampire
# 33      The Joy Luck Club
# 12      Snow Falling on Cedars
# 25      She's Come Undone (Oprah's Book Club (Paperback))
# 4       Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 3       The Red Tent (Bestselling Backlist)
# 5       Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# 17      House of Sand and Fog
# 8       A Painted House
# 0       The Lovely Bones: A Novel
# 2       The Da Vinci Code
# 1       Wild Animus
# 2718    The Five Love Languages: Five Love Languages
# 78636   The Winter's Tale - Arden Shakespeare : Third Series - Hardback (Arden Shakespeare Third Series)
# 134112  Deep Waters
# 106324  Monkey (An Evergreen Book, E-112)
# 30975   Edgar Allen Poe Collected Poems
# 37056   Heidi
# 19470   Das groÃ?Â?e BÃ?Â¶se- MÃ?Â¤dchen- Lesebuch.
# 13544   MY TEACHER FRIED MY BRAINS (RACK SIZE) (MY TEACHER BOOKS)
# 124233  To Have and Have Not
# 30761   Three Plays of Eugene Oneill
# 23915   Alice's Adventures in Wonderland and Through the Looking Glass (Puffin Books)
#
#                       Book-Author  Year-Of-Publication  \
# 199     Arthur Golden              0
# 50958   IsmaÂ°il Fasih             1376
# 51049   Nazi Safavi                1378
# 130403  Benjamin Franklin          1806
# 92641   Ted Schredd                1900
# 122731  Jd Hersey                  1901
# 45038   Linda O. Johnston          1902
# 104397  JOSEPH HELLER              1904
# 103215  Clement K. Shorter         1906
# 25641   Three Initiates            1908
# 54283   Emanuel Swedenborg         1911
# 5181    F. Scott Fritzgerald       1920
# 23741   BEVERLY CLEARY             1923
# 138194  Albert Einstein            1924
# 43202   F. Scott Fitzgerald        1925
# 22701   Ernest Hemingway           1926
# 10647   Franklin W. Dixon          1927
# 50654   Percival C. Wren           1928
# 7190    Ernest Hemingway           1929
# 1609    Carolyn Keene              1930
# 129743  Kenneth McLeish            1931
# 12323   Carolyn Keene              1932
# 62699   Charlotte Bronte           1933
# 82320   Elizabeth Reynard          1934
# 53389   Myer Pearlman              1935
# 16453   Margaret Mitchell          1936
# 20542   Charles Williams           1937
# 9375    J. R. R. Tolkien           1938
# 50711   Leslie Charteris           1939
# 36882   C.B. Colby                 1940
# 36522   Akiba Rubinstein           1941
# 9284    Aldous Huxley              1942
# 22813   Antoine De Saint-Exupery   1943
# 101864  WALTER FARLEY              1944
# 11400   E. B. White                1945
# 7724    Charles Lutwidge Dodgson   1946
# 15263   Carolyn Keene              1947
# 19388   Karl Marx                  1948
# 15266   Carolyn Keene              1949
# 10120   EDMOND ROSTAND             1950
# 4987    Hermann Hesse              1951
# 4208    E. B. White                1952
# 1118    Laura Ingalls Wilder       1953
# 2124    Willa Sibert Cather        1954
# 5202    Dudley Fitts               1955
# 3474    Allen Ginsberg             1956
# 1013    Dr. Seuss                  1957
# 3572    Dr. Seuss                  1958
# 119     William Gerald Golding     1959
# 1746    Dr. Seuss                  1960
# 3573    Philip D. Eastman          1961
# 8265    Juan Mascaro               1962
# 2276    Dr. Seuss                  1963
# 2107    Shel Silverstein           1964
# 754     NATHANIEL HAWTHORNE        1965
# 2618    Robert Ludlum              1966
# 5985    Jonathan Swift             1967
# 504     Antoine de Saint-ExupÃ©ry  1968
# 4541    LLOYD ALEXANDER            1969
# 1193    C.S. Lewis                 1970
# 737     SCOTT O'DELL               1971
# 1095    FRANZ KAFKA                1972
# 1877    Kahlil Gibran              1973
# 302     E. B. White                1974
# 1825    Piers Paul Read            1975
# 137     Richard Adams              1976
# 2550    Roger Zelazny              1977
# 263     Colleen McCullough         1978
# 1705    Madeleine L'Engle          1979
# 545     M. Scott Peck              1980
# 469     Hermann Hesse              1981
# 174     Elie Wiesel                1982
# 132     Benjamin Hoff              1983
# 186     Jean M. Auel               1984
# 385     Alice Walker               1985
# 48      J.R.R. TOLKIEN             1986
# 46      RAY BRADBURY               1987
# 23      Harper Lee                 1988
# 106     Barbara Kingsolver         1989
# 37      John Irving                1990
# 13      J.D. Salinger              1991
# 24      John Grisham               1992
# 16      Anne Rice                  1993
# 33      Amy Tan                    1994
# 12      David Guterson             1995
# 25      Wally Lamb                 1996
# 4       Rebecca Wells              1997
# 3       Anita Diamant              1998
# 5       J. K. Rowling              1999
# 17      Andre Dubus III            2000
# 8       John Grisham               2001
# 0       Alice Sebold               2002
# 2       Dan Brown                  2003
# 1       Rich Shapero               2004
# 2718    Gary Chapman               2005
# 78636   John Pitcher               2006
# 134112  Jayne Ann Krentz           2010
# 106324  Cheng-En Wu                2011
# 30975   Edgar Allan Poe            2020
# 37056   Johanna Spyri              2021
# 19470   Kathy Lette                2026
# 13544   Coville                    2030
# 124233  Ernest Hemingway           2037
# 30761   Eugene O'Neill             2038
# 23915   Lewis Carroll              2050
#
#                                     Publisher
# 199     Trafalgar Square
# 50958   Nashr-i Alburz
# 51049   Intisharat-i Quqnus
# 130403  Reprint Services Corp
# 92641   Graphic Arts Center Pub Co
# 122731  Simon &amp; Schuster
# 45038   Harlequin
# 104397  Delta
# 103215  Ams Pr
# 25641   Yoga Publication Society
# 54283   Steiner Books
# 5181    Scribner Paper Fiction
# 23741   Yearling
# 138194  Dover Publications
# 43202   Prentice Hall
# 22701   Scribner Book Company
# 10647   Grosset &amp; Dunlap
# 50654   Stokes Pub Co
# 7190    Charles Scribner's Sons
# 1609    Grosset &amp; Dunlap
# 129743  Trafalgar Square Publishing
# 12323   Imagination Studio
# 62699   Gateway/Associated Faculty Pr
# 82320   Parnassus Press
# 53389   Gospel Publishing House
# 16453   Scribner
# 20542   Wm. B. Eerdmans Publishing Company
# 9375    Houghton Mifflin Company
# 50711   Doubleday
# 36882   Scholastic Paperbacks (Mm)
# 36522   Dover Publications
# 9284    Perennial
# 22813   Harcourt
# 101864  Random House Books for Young Readers
# 11400   HarperCollins
# 7724    Grosset &amp; Dunlap
# 15263   Grosset &amp; Dunlap
# 19388   International Publishers
# 15266   Grosset &amp; Dunlap
# 10120   Bantam
# 4987    New Directions Publishing Corporation
# 4208    Harpercollins Juvenile Books
# 1118    HarperTrophy
# 2124    Houghton Mifflin
# 5202    Harvest Books
# 3474    City Lights Publishers
# 1013    Random House Books for Young Readers
# 3572    Random House Books for Young Readers
# 119     Perigee Trade
# 1746    Random House Books for Young Readers
# 3573    Random House Children's Books
# 8265    Penguin Books
# 2276    Random House Books for Young Readers
# 2107    HarperCollins Publishers
# 754     Bantam
# 2618    Bantam Doubleday Dell
# 5985    Penguin Books
# 504     Harcourt
# 4541    Yearling
# 1193    MacMillan Publishing Company.
# 737     Random House Children's Books
# 1095    Bantam
# 1877    Alfred A. Knopf
# 302     HarperTrophy
# 1825    Avon
# 137     Avon
# 2550    Avon
# 263     Avon
# 1705    Laure Leaf
# 545     Touchstone
# 469     Bantam Classics
# 174     Bantam Books
# 132     Penguin Books
# 186     Bantam Books
# 385     Pocket Books
# 48      Del Rey
# 46      Del Rey
# 23      Little Brown &amp; Company
# 106     Perennial
# 37      Ballantine Books
# 13      Little, Brown
# 24      Bantam Dell Publishing Group
# 16      Ballantine Books
# 33      Prentice Hall (K-12)
# 12      Vintage Books USA
# 25      Washington Square Press
# 4       Perennial
# 3       Picador USA
# 5       Arthur A. Levine Books
# 17      Vintage Books
# 8       Dell Publishing Company
# 0       Little, Brown
# 2       Doubleday
# 1       Too Far
# 2718    Moody Publishers
# 78636   Arden
# 134112  Pocket
# 106324  Grove Press
# 30975   Bausch &amp; Lombard
# 37056   Scholastic
# 19470   Goldmann
# 13544   Aladdin
# 124233  Simon &amp; Schuster
# 30761   Vintage Books USA
# 23915   Puffin Books
